# %% [raw]
# ---
# title: "Quiz7 (2026.04.29)"
# author: "최규빈"
# date: "04/29/2026"
# draft: false
# ---

# %% [markdown]
# <a href="https://colab.research.google.com/github/guebin/STSC2026/blob/master/posts/Quiz7.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" style="text-align: left"></a>

# %% [markdown]
# {{<video https://youtu.be/AQLeYVV_ou4>}}

# %% [markdown]
# # 1. -- 50점

# %% [markdown]
# 아래와 같은 기능을 하도록 클래스 `Greet` 을 설계하라.

# %% [markdown]
# `# 예시1`
#
# ```python
# g = Greet("보람")
# ```
# ```bash
# 보람님, 환영합니다.
# ```
# ```python
# g.name
# ```
# ```bash
# '보람'
# ```
# ```python
# g.hello()
# ```
# ```bash
# 안녕! 나는 보람이야.
# ```

# %% [markdown]
# `# 예시2`
#
# ```python
# g = Greet("규빈")
# ```
# ```bash
# 규빈님, 환영합니다.
# ```
# ```python
# g.hello()
# ```
# ```bash
# 안녕! 나는 규빈이야.
# ```

# %% [markdown]
# # 2. -- 50점

# %% [markdown]
# 아래와 같은 기능을 하도록 클래스 `Light` 를 설계하라.

# %% [markdown]
# `# 예시`
#
# ```python
# lamp = Light()
# lamp
# ```
# ```bash
# 현재상태: OFF
# ```
# ```python
# lamp.on()
# lamp
# ```
# ```bash
# 현재상태: ON
# ```
# ```python
# lamp.off()
# lamp
# ```
# ```bash
# 현재상태: OFF
# ```
