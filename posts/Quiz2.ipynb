# %% [raw]
# ---
# title: "Quiz-2 (2026.03.18)"
# author: "최규빈"
# date: "03/18/2026"
# draft: true
# ---

# %% [markdown]
# <a href="https://colab.research.google.com/github/guebin/STSC2026/blob/main/posts/Quiz2.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" style="text-align: left"></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 문제 1. 미분

# %% [markdown]
# 함수 $f(x)=\sin(2x)$ 를 입력하면 도함수를 리턴하는 함수를 파이썬으로 구현하라. 이러한 함수를 이용하여 $f(x)$, $f'(x)$, $f''(x)$, $f^{(3)}(x)$, $f^{(4)}(x)$의 그래프를 한 Figure에 모두 그려라. (범례는 표현하지 않아도 감점없음)

# %% [markdown]
# - $x$의 범위는 $(-6,6)$ 로 할 것.
# - tip: 욕심부려서 $h$의 값을 너무 작게 설정하면 그림이 예쁘게 안나옵니다.

# %% [markdown]
# # 문제 2. 적분

# %% [markdown]
# 몬테카를로 시뮬레이션을 이용하여 다음을 계산하라.

# %% [markdown]
# `(1)` 다음 적분값을 근사계산하라.
#
# $$\int_{-1.96}^{1.96} \frac{1}{\sqrt{2\pi}}e^{-x^2/2} \, dx$$

# %% [markdown]
# `(2)` 시뮬레이션을 이용하여 원주율 $\pi$를 추정하라.
